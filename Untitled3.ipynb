# %% [markdown]
# <a href="https://colab.research.google.com/github/leviettienduong/leduongdepzai/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tong_chan = 0
tong_le = 0
for i in range(1, 11):
    if i % 2 == 0:
        tong_chan = tong_chan + i
    else:
        tong_le = tong_le + i
print(tong_chan)
print(tong_le)
# Out:
# 30
# 25
